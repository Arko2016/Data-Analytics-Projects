# %%
#load required packages
import pandas as pd
import numpy as np

# %%
#import data from github repo
#original github repo for file
#url = "https://github.com/pik1989/Sales-Analysis/raw/main/Regional%20Sales%20Dataset.xlsx"
url = "https://github.com/Arko2016/Data-Analytics-Projects/raw/main/Retail%20Sales%20Analysis/Regional%20Sales%20Dataset.xlsx"
sheets = pd.ExcelFile(url)
data_tabs = ', '.join(sheets.sheet_names)
print("Data tabs:",data_tabs)

for i in sheets.sheet_names:
  #remove white spaces and appropriate create dataframe name
  df_name = "df_"+ i.replace(" ","")
  globals()[df_name] = sheets.parse(i)
  print("Dataframe Created:",df_name)
# Out:
# Data tabs: Sales Orders, Customers, Regions, State Regions, Products, 2017 Budgets
# Dataframe Created: df_SalesOrders
# Dataframe Created: df_Customers
# Dataframe Created: df_Regions
# Dataframe Created: df_StateRegions
# Dataframe Created: df_Products
# Dataframe Created: df_2017Budgets
#     OrderNumber  OrderDate  Customer Name Index      Channel Currency Code  \
# 0   SO - 000225 2014-01-01                  126    Wholesale           USD
# 1  SO - 0003378 2014-01-01                   96  Distributor           USD
# 2  SO - 0005126 2014-01-01                    8    Wholesale           USD
# 3  SO - 0005614 2014-01-01                   42       Export           USD
# 4  SO - 0005781 2014-01-01                   73    Wholesale           USD
#
#   Warehouse Code  Delivery Region Index  Product Description Index  \
# 0         AXW291                    364                         27
# 1         AXW291                    488                         20
# ...
